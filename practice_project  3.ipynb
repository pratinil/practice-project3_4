# %%
import pandas as pd                 
import numpy as np                  
import seaborn as sns              
import matplotlib.pyplot as plt      # for plotting graphs
plt.style.use('seaborn')          # the seaborn stylesheet will make our plots look neat and pretty.
sns.set_style('darkgrid')
plt.rcParams['font.size']=15
plt.rcParams['figure.figsize']=(10,7)
plt.rcParams['figure.facecolor']='#FFE5B4'
# %matplotlib inline                   
# "%matplotlib inline" ensures commands in cells below the cell that outputs a plot does not affect the plot
    
import warnings                      
warnings.filterwarnings("ignore")

data= pd.read_csv("https://raw.githubusercontent.com/dsrscientist/DSData/master/happiness_score_dataset.csv")
# DISPLAY THE DATASET:
data
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
data.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
data_columns=['Country','Region','Happiness Rank','Happiness Score','Standard Error','Economy (GDP per Capita)','Family','Health (Life Expectancy)','Freedom','Trust (Government Corruption)','Generosity','Dystopia Residual']

# %%
#data = data[data_columns].copy()
data = data[data_columns].copy()

# %%
#convert our df name -data into happy_df:
happy_df=data

# %%
# Display first rows:
happy_df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
happy_df.tail()
# Out:
#      Country                           Region  Happiness Rank  \
# 153   Rwanda               Sub-Saharan Africa             154
# 154    Benin               Sub-Saharan Africa             155
# 155    Syria  Middle East and Northern Africa             156
# 156  Burundi               Sub-Saharan Africa             157
# 157     Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 153            3.465         0.03464                   0.22208  0.77370
# 154            3.340         0.03656                   0.28665  0.35386
# 155            3.006         0.05015                   0.66320  0.47489
# 156            2.905         0.08658                   0.01530  0.41587
# 157            2.839         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 153                   0.42864  0.59201                        0.55191
# ...

# %%
happy_df.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
# Check dataframe shape:
happy_df.shape
# Out:
# (158, 12)

# %%
#statistical description:
happy_df.describe
# Out:
# <bound method NDFrame.describe of          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# ...

# %%
#Checking null values:
happy_df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
# check gdp in different regions:
gdp_region=happy_df.groupby('Region')['Economy (GDP per Capita)'].sum()
gdp_region
# Out:
# Region
# Australia and New Zealand           2.58376
# Central and Eastern Europe         27.33071
# Eastern Asia                        6.91068
# Latin America and Caribbean        19.28994
# Middle East and Northern Africa    21.33947
# North America                       2.72080
# Southeastern Asia                   7.10149
# Southern Asia                       3.92340
# Sub-Saharan Africa                 15.21892
# Western Europe                     27.27051
# Name: Economy (GDP per Capita), dtype: float64

# %%
#here we can see the gdp in different regions.

# %%
#gdp in different regions using pie figure:
gdp_region.plot.pie(autopct='%1.1f%%')
plt.title('GDP by Region')
plt.ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
# CONCLUSION: -we can see the highest GDP in western Europe & Central and Eastern Europe.

# -western Europe & Central AND Eastern Europe both are contributing 20.4 % to the world GDP.

# Middle East and Northern Africa is contributing more than others 16.0% to the world GDP.

# Least-Northern America is contributing very less 2.0% to the world america.

# %%
# we will see here total name of countries in each region:
Total_country=happy_df.groupby('Region')['Country'].sum()
print(Total_country)
# Out:
# Region
# Australia and New Zealand                                       New ZealandAustralia
# Central and Eastern Europe         Czech RepublicUzbekistanSlovakiaMoldovaKazakhs...
# Eastern Asia                            TaiwanJapanSouth KoreaHong KongChinaMongolia
# Latin America and Caribbean        Costa RicaMexicoBrazilVenezuelaPanamaChileArge...
# Middle East and Northern Africa    IsraelUnited Arab EmiratesOmanQatarSaudi Arabi...
# North America                                                    CanadaUnited States
# Southeastern Asia                  SingaporeThailandMalaysiaIndonesiaVietnamPhili...
# Southern Asia                      BhutanPakistanBangladeshIndiaNepalSri LankaAfg...
# Sub-Saharan Africa                 MauritiusNigeriaZambiaSomaliland regionMozambi...
# Western Europe                     SwitzerlandIcelandDenmarkNorwayFinlandNetherla...
# Name: Country, dtype: object

# %%
#Data Analysis and Visualization:
    #Data Analysis and Visualization
#Univariate plots are used to understand each feature. Histograms were used to view the frequency distribution of the variables.

# checking the frequency distribution of the variables

happy_df.hist(bins='auto', figsize=(15,15));

# %%
# checking for outliers with boxplots
happy_df[['Happiness Score', 'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)', 'Freedom', 'Generosity', 'Trust (Government Corruption)']].plot(kind='box', subplots=True, layout=(4,4), figsize=(10,8), grid=True);

# %%
#Conclusion:Outliers were checked for using boxplots. 
    #The output shows there are outliers in the Family, Generosity, and Trust.

# %%
#Correlation Map:
cor = happy_df.corr(method='pearson')
f,ax =plt.subplots(figsize=(15,5))
sns.heatmap(cor,mask =np.zeros_like(cor,dtype=np.bool),
            cmap='Reds',square=True,ax=ax)
# Out:
# <AxesSubplot:>

# %%
# conclusion: As we can see here 'Happiness score' is highly corelated with- 'economy' , 'Family' , 'Health' , 'Freedom' ,

# 'Trust' and some lightly with 'generosity' also.

# %%
# What countries have the highest GDP per capita over the years?
rich_countries = happy_df[['Country', 'Economy (GDP per Capita)']].groupby('Country').mean().sort_values(by='Economy (GDP per Capita)', ascending=False)
rich_countries.head()
# Out:
#             Economy (GDP per Capita)
# Country
# Qatar                        1.69042
# Luxembourg                   1.56391
# Kuwait                       1.55422
# Singapore                    1.52186
# Norway                       1.45900

# %%
# Some of the saddest countries on average
sad_countries = happy_df[['Country', 'Happiness Rank']].groupby('Country').mean().sort_values(by = 'Happiness Rank', ascending = True)
sad_countries.tail()
# Out:
#          Happiness Rank
# Country
# Rwanda            154.0
# Benin             155.0
# Syria             156.0
# Burundi           157.0
# Togo              158.0

# %%
# Five countries with the highest life expectancy
healthy_countries = happy_df[['Country', 'Health (Life Expectancy)']].sort_values(by='Health (Life Expectancy)', ascending=False)
healthy_countries.head()
# Out:
#         Country  Health (Life Expectancy)
# 23    Singapore                   1.02525
# 71    Hong Kong                   1.01328
# 45        Japan                   0.99111
# 46  South Korea                   0.96538
# 35        Spain                   0.95562

# %%
# Some countries with extremely low life expectancy
low_healthy_countries = happy_df[['Country', 'Health (Life Expectancy)']].sort_values(by='Health (Life Expectancy)', ascending=False)
low_healthy_countries.tail()
# Out:
#                       Country  Health (Life Expectancy)
# 96                    Lesotho                   0.07612
# 100                 Swaziland                   0.07566
# 147  Central African Republic                   0.06699
# 127                  Botswana                   0.04776
# 122              Sierra Leone                   0.00000

# %%
# We will use here mean() to see average happiness_rank in regions .
Happiness_Rank=happy_df.groupby('Region')[['Happiness Rank']].mean()
Happiness_Rank
# Out:
#                                  Happiness Rank
# Region
# Australia and New Zealand              9.500000
# Central and Eastern Europe            79.000000
# Eastern Asia                          64.500000
# Latin America and Caribbean           46.909091
# Middle East and Northern Africa       77.600000
# North America                         10.000000
# Southeastern Asia                     81.222222
# Southern Asia                        113.142857
# Sub-Saharan Africa                   127.900000
# Western Europe                        29.523810

# %%
# .Highest Happiness_Rank:

# -We can see here the highest 'Happiness_Rank'(113.142957) in Southern Asia

# and (127.900000)'Happiness_Rank' in Sub-Saharan Africa.

# .Lowest Happiness_Rank

# -We can see here the lowest 'Happiness_Rank'(29.523810) in Western Europe

# and (10.000000)'Happiness_Rank' in North America.

# %%
# We will use here mean() to see average Standard_Error in regions .
Standard_Error=happy_df.groupby('Region')[['Standard Error']].mean()
Standard_Error
# Out:
#                                  Standard Error
# Region
# Australia and New Zealand              0.037270
# Central and Eastern Europe             0.045208
# Eastern Asia                           0.037225
# Latin America and Caribbean            0.061127
# Middle East and Northern Africa        0.046337
# North America                          0.036960
# Southeastern Asia                      0.042691
# Southern Asia                          0.032161
# Sub-Saharan Africa                     0.055299
# Western Europe                         0.037625

# %%
# CONCLUSION: -Here we can see Sub-Saharan Africa and Middle East and Northern Africa have highest Standard_Error.

# -Here we can see Southern Asia has lowest Standard_Error.

# %%
# We will use here mean() to see average Trust(Perception of Corruption) in region .
Trust=happy_df.groupby('Region')[['Trust (Government Corruption)']].mean()
Trust
# Out:
#                                  Trust (Government Corruption)
# Region
# Australia and New Zealand                             0.392795
# Central and Eastern Europe                            0.086674
# Eastern Asia                                          0.127695
# Latin America and Caribbean                           0.117172
# Middle East and Northern Africa                       0.181702
# North America                                         0.244235
# Southeastern Asia                                     0.151276
# Southern Asia                                         0.102536
# Sub-Saharan Africa                                    0.123878
# Western Europe                                        0.231463

# %%
# CONCLUSION: -here we can see Australia and New Zealand & North America has highest Trust(Perception of Corruption).

# -here we can see Central and Eastern Europe has lowest Trust(Perception of Corruption).
#happy_df.rename({'Health (Life Expectancy)' : 'health'}, axis=1)
happy_df.rename(columns = {'Health (Life Expectancy)':'health'}, inplace = True)
happy_df.rename(columns = {'Economy (GDP per Capita)':'economy'}, inplace = True)
happy_df.rename(columns = {'Happiness Score':'Happiness_Score'}, inplace = True)
happy_df.rename(columns = {'Happiness Rank':'Happiness_Rank'}, inplace = True)
happy_df.rename(columns = {'Trust (Government Corruption)':'Trust'}, inplace = True)
happy_df.rename(columns = {'Dystopia Residual':'Dystopia_Residual'}, inplace = True)
# After renaming the columns
print("\nAfter modifying first column:\n", happy_df.columns)
# Out:
# After modifying first column:
#  Index(['Country', 'Region', 'Happiness_Rank', 'Happiness_Score',
#        'Standard Error', 'economy', 'Family', 'health', 'Freedom', 'Trust',
#        'Generosity', 'Dystopia_Residual'],
#       dtype='object')

# %%
#Here we will check the top 10 happiest and bottom 10 least happy countries.
top_10 = happy_df.head(10)
bottom_10 = happy_df.tail(10)
happy_df.head()
# Out:
#        Country          Region  Happiness_Rank  Happiness_Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  economy   Family   health  Freedom    Trust  Generosity  \
# 0         0.03411  1.39651  1.34951  0.94143  0.66557  0.41978     0.29678
# 1         0.04884  1.30232  1.40223  0.94784  0.62877  0.14145     0.43630
# 2         0.03328  1.32548  1.36058  0.87464  0.64938  0.48357     0.34139
# 3         0.03880  1.45900  1.33095  0.88521  0.66973  0.36503     0.34699
# 4         0.03553  1.32629  1.32261  0.90563  0.63297  0.32957     0.45811
#
#    Dystopia_Residual
# 0            2.51738
# 1            2.70201
# 2            2.49204
# 3            2.46531
# ...

# %%
fig, axes= plt.subplots(1,2, figsize =(16,6))
plt.tight_layout(pad= 2)
xlabels= top_10.Country
axes[0].set_title('Top 10 happiest countries Life Expectancy')
axes[0].set_xticklabels(xlabels, rotation=45, ha='right')
sns.barplot(x= top_10.Country,y=top_10.health, ax=axes[0])
axes[0].set_xlabel('Country Name')
axes[0].set_ylabel('health')

xlabels= bottom_10.Country
axes[1].set_title('Top 10  least Happy countries Life EXpectancy')
axes[1].set_xticklabels(xlabels, rotation=45, ha='right')
sns.barplot(x= bottom_10.Country,y=bottom_10.health, ax=axes[1])
axes[1].set_xlabel('Country')
axes[1].set_ylabel('health')
# Out:
# Text(841.7108585858584, 0.5, 'health')

# %%
# top 10 happiest with Freedom and least happy countries name:
fig, axes= plt.subplots(1,2, figsize =(16,6))
plt.tight_layout(pad= 2)
xlabels= top_10.Country
axes[0].set_title('Top 10 happiest countries Freedom')
axes[0].set_xticklabels(xlabels, rotation=45, ha='right')
sns.barplot(x= top_10.Country,y=top_10.Freedom, ax=axes[0])
axes[0].set_xlabel('Country Name')
axes[0].set_ylabel('Generosity')

xlabels= bottom_10.Country
axes[1].set_title('Top 10  least Happy countries Freedom')
axes[1].set_xticklabels(xlabels, rotation=45, ha='right')
sns.barplot(x= bottom_10.Country,y=bottom_10.Freedom, ax=axes[1])
axes[1].set_xlabel('Country Name')
axes[1].set_ylabel('Freedom')
# Out:
# Text(841.7108585858584, 0.5, 'Freedom')

# %%
# top 10 happiest with generosity and least happy countries name:
fig, axes= plt.subplots(1,2, figsize =(16,6))
plt.tight_layout(pad= 2)
xlabels= top_10.Country
axes[0].set_title('Top 10 happiest countries Generosity')
axes[0].set_xticklabels(xlabels, rotation=45, ha='right')
sns.barplot(x= top_10.Country,y=top_10.Generosity, ax=axes[0])
axes[0].set_xlabel('Country Name')
axes[0].set_ylabel('Generosity')

xlabels= bottom_10.Country
axes[1].set_title('Top 10  least Happy countries Generosity')
axes[1].set_xticklabels(xlabels, rotation=45, ha='right')
sns.barplot(x= bottom_10.Country,y=bottom_10.Generosity, ax=axes[1])
axes[1].set_xlabel('Country Name')
axes[1].set_ylabel('Generosity')
# Out:
# Text(841.7108585858584, 0.5, 'Generosity')

# %%
# top 10 happiest with Family satisfaction and least happy countries name:
fig, axes= plt.subplots(1,2, figsize =(16,6))
plt.tight_layout(pad= 2)
xlabels= top_10.Country
axes[0].set_title('Top 10 happiest countries Family')
axes[0].set_xticklabels(xlabels, rotation=45, ha='right')
sns.barplot(x= top_10.Country,y=top_10.Family, ax=axes[0])
axes[0].set_xlabel('Country Name')
axes[0].set_ylabel('Family')

xlabels= bottom_10.Country
axes[1].set_title('Top 10  least Happy countries Family')
axes[1].set_xticklabels(xlabels, rotation=45, ha='right')
sns.barplot(x= bottom_10.Country,y=bottom_10.Family, ax=axes[1])
axes[1].set_xlabel('Country Name')
axes[1].set_ylabel('Family')
# Out:
# Text(841.7108585858584, 0.5, 'Family')

# %%
fig, axes= plt.subplots(1,2, figsize =(16,6))
plt.tight_layout(pad= 2)
xlabels= top_10.Country
axes[0].set_title('Top 10 happiest countries Trust')
axes[0].set_xticklabels(xlabels, rotation=45, ha='right')
sns.barplot(x= top_10.Country,y=top_10.Trust, ax=axes[0])
axes[0].set_xlabel('Country Name')
axes[0].set_ylabel('Trust')

xlabels= bottom_10.Country
axes[1].set_title('Top 10  least Happy countries Trust')
axes[1].set_xticklabels(xlabels, rotation=45, ha='right')
sns.barplot(x= bottom_10.Country,y=bottom_10.Trust, ax=axes[1])
axes[1].set_xlabel('Country Name')
axes[1].set_ylabel('Trust')
# Out:
# Text(841.7108585858584, 0.5, 'Trust')

# %%
#plot b/w happiness and GDP:
plt.rcParams['figure.figsize'] = (15,7)
plt.title('plot between happiness and GDP')
sns.scatterplot(x =happy_df.Happiness_Score , y = happy_df.economy, hue =happy_df.Region , s=200);
plt.legend(loc = 'upper left',fontsize ='10')
plt.xlabel('Happiness_Score')
plt.ylabel('economy	')
# Out:
# Text(0, 0.5, 'economy\t')

# %%
#-here we can see the countries have highest happiness score or GDP per capita=Western europe,North America ,Australia and Newzland

#-here we can remain countries have lowest happiness score and GDP per Capita .

#Here we will check in figure -Freedom to make life choices and Happiness_score using Scatter Plot method.

# %%
plt.rcParams['figure.figsize']=(15,7)
sns.scatterplot(x=happy_df.Freedom,y=happy_df.Happiness_Score, hue = happy_df.Region,s=200)
plt.legend(loc = 'upper left',fontsize ='12')
plt.ylabel('Happiness_Score')
# Out:
# Text(0, 0.5, 'Happiness_Score')

# %%
#Conclusion:
#-here we can see the western europe has highest freedom to make life choices and also highest Happiness_Score
#-North America has highest freedom to make life choices and also highest Happiness_Score
#-Australia and New zealand has highest freedom to make life choices and also highest Happiness_Score

#-Middle East and Northern Africa has very low freedom to make life choices and also  very low  Happiness_Score
#-Sub-Saharan Africa has very low freedom to make life choices and it has less Happiness_Score.
#-Southern Asia has higher freedom to make life choices but it has less Happiness_Score.  
# Here we will see Family(Social Support) here named as Family and happiness score in this figure using scatterplot:

# %%
plt.rcParams['figure.figsize']=(15,7)
sns.scatterplot(x=happy_df.Family,y=happy_df.Happiness_Score, hue = happy_df.Region,s=200)
plt.legend(loc = 'upper left',fontsize ='12')
plt.ylabel('Happiness_Score')
# Out:
# Text(0, 0.5, 'Happiness_Score')

# %%
#Conclusion: Here we can see the Sub-Saharan Africa and Middle East and Northern Africa have lowest Happiness score but higher in social support(Family).

 #   Middle East and Northern Africa ,Latin America and Caribbean,Southern ASia have highest Family(Social support)but lower         happiness score.

  #  Western Europe has highest Family(social Support) but less happiness score.

   # North America has highest happiness score as well as Family(Social support).
    #-Here,we will see Health(Life Excpectancy) which is named as Family and happiness score in this figure using scatterplot:

# %%
plt.rcParams['figure.figsize']=(15,7)
sns.scatterplot(x=happy_df.health,y=happy_df.Happiness_Score, hue = happy_df.Region,s=200)
plt.legend(loc = 'upper left',fontsize ='12')
plt.ylabel('Happiness_Score')
# Out:
# Text(0, 0.5, 'Happiness_Score')

# %%
#Conclusion:South Eastern Asia has highest health (life expectancy) and highest happiness score.

#Eastern Asia has highest health(Life Expectancy) but less happiness score.

#Sub-Saharan Africa has lowest lowest Happiness score as well as lowest health (life expectancy)
#Here we will see Generosity and happiness score in this figure using scatterplot:

# %%
plt.rcParams['figure.figsize']=(15,7)
sns.scatterplot(x=happy_df.Generosity,y=happy_df.Happiness_Score, hue = happy_df.Region,s=200)
plt.legend(loc = 'upper left',fontsize ='12')
plt.ylabel('Happiness_Score')
# Out:
# Text(0, 0.5, 'Happiness_Score')

# %%
#Conclusion:

#-Central and Eastern Europe has highest generosity but less happiness score.

#-Sub-Saharan Africa ,Middle East and North Africa have lowest happiness score and average generosity not higher.
#Here we will see GDP_per_Capita and Happiness score in figure using scatterplot method:

# %%
plt.rcParams['figure.figsize']=(15,7)
sns.scatterplot(x=happy_df.economy,y=happy_df.Happiness_Score, hue = happy_df.Region,s=200)
plt.legend(loc = 'upper left',fontsize ='12')
plt.ylabel('Happiness_Score')
# Out:
# Text(0, 0.5, 'Happiness_Score')

# %%
#Conclusion: South Eastern Asia has highest GDP_per_Capita and average happiness score.

#Western Europe has highest GDP_per_Capita and average happiness score.

#Sub-Saharan Africa has lowest happiness score and also lowest GDP_per_Capita.

#Middle East and North Africa has lowest happiness score but highest GDP_per_Capita

# %%
#- Here we will check 10 countries have most Corruption and less corruption using head and tail () method.
# -here perceptions of corruption is named by Trust.

# %%
country = happy_df.sort_values(by='Trust').head(10)
plt.rcParams['figure.figsize']=(12,6)
plt.title('Countries with Most Trust')
plt.xlabel('Country',fontsize =13)
plt.ylabel('Trust Index',fontsize =13)
plt.xticks(rotation= 30, ha= 'right')
plt.bar(country.Country, country.Trust)
# Out:
# <BarContainer object of 10 artists>

# %%
# here we can see the lowest Trust(Perception of corruption)
              
country = happy_df.sort_values(by='Trust').tail(10)
plt.rcParams['figure.figsize']=(12,6)
plt.title('Countries with Most Trust')
plt.xlabel('Country',fontsize =13)
plt.ylabel('Trust Index',fontsize =13)
plt.xticks(rotation= 30, ha= 'right')
plt.bar(country.Country, country.Trust)
# Out:
# <BarContainer object of 10 artists>

# %%
#Corruption vs happiness:
plt.rcParams['figure.figsize']=(15,7)
sns.scatterplot(x=happy_df.Happiness_Score,y=happy_df.Trust,hue=happy_df.Region,s=200)
plt.legend(loc='lower left',fontsize='14')
plt.xlabel('Happiness_Score')
plt.ylabel('Trust')
# Out:
# Text(0, 0.5, 'Trust')

# %%
#Conclusion =>here we can see (Western Europe ,north America,Australia and New Zealand ,Middle East and Northern Africa) have

#highest happiness score.

#here we can see the almost all the countries have low (Trust)corruption rate .

#Central and Eastern Europe has lowest (Trust)corruption

# %%
#Cleaning:

# %%
#We’ll drop the Country feature because it’s categorical, 
#we’ll also drop the happiness rank and year variable because they are not relevant to the model, 
#  leaving just numerical features for the modeling.

#  Dropping irrelevant variables
new_happy_df = happy_df.drop(['Country', 'Happiness_Rank','Region'], axis=1)
new_happy_df.head()
#new_happiness.info()
# Out:
#    Happiness_Score  Standard Error  economy   Family   health  Freedom  \
# 0            7.587         0.03411  1.39651  1.34951  0.94143  0.66557
# 1            7.561         0.04884  1.30232  1.40223  0.94784  0.62877
# 2            7.527         0.03328  1.32548  1.36058  0.87464  0.64938
# 3            7.522         0.03880  1.45900  1.33095  0.88521  0.66973
# 4            7.427         0.03553  1.32629  1.32261  0.90563  0.63297
#
#      Trust  Generosity  Dystopia_Residual
# 0  0.41978     0.29678            2.51738
# 1  0.14145     0.43630            2.70201
# 2  0.48357     0.34139            2.49204
# 3  0.36503     0.34699            2.46531
# 4  0.32957     0.45811            2.45176

# %%
#Splitting data:

# %%
#With the result of the correlation matrix, we can do some feature selection. 
#The features with the strongest correlation with the target variable will be selected.

#Next, we split the data into training and test sets.

# splitting data
from sklearn.model_selection import train_test_split

# features with low corelation has been removed:

X = new_happy_df[['economy', 'Family', 'health', 'Freedom']]
y = new_happy_df['Happiness_Score']

# %%
# X = features, y = target variable
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size = 0.2, random_state=0)
y_pred = lm.predict(X_test)

# %%
# We need to scale the data before feeding it to the model
# To standardize our data, we import the StandardScaler from the sklearn library
from sklearn.preprocessing import StandardScaler 

scale = StandardScaler()

new_happy_df = scale.fit_transform(new_happy_df)

# %%
#After standardizing, we will here train the algorithm, 
#make predictions on the test data, and compare actual values with the predicted values.

# Training the algorithm

from sklearn.linear_model import LinearRegression

lm = LinearRegression()                   # instantiating the model

lm.fit(X_train, y_train)                      # fitting the model with the training dataset
# Out:
# LinearRegression()

# %%
#making a dataframe of the coeffiecients to help us easily determine which variable carries more weight
coefficient = lm.coef_

coefficient_df = pd.DataFrame(list(zip(X.columns, lm.coef_)), columns=['features', 'coefficients'])
coefficient_df
# Out:
#   features  coefficients
# 0  economy      0.914757
# 1   Family      1.418679
# 2   health      0.902836
# 3  Freedom      1.934132

# %%
#here we can see the Freedom feature has a higher model correlation to the target variable as opposed to GDP per capita.

# %%
#Model Evaluation:
from sklearn import metrics
from sklearn.metrics import mean_squared_error as MSE


print('Root Mean Squared Error:', np.sqrt(MSE(y_pred,y_test)))
# Out:
# Root Mean Squared Error: 0.5937109307075936

# %%
#Conclusion:
#-GDP_per_Capita, freedom to make life choices, and Health(Life expectancy) are significant determinants of Happiness score.
#Family is also important because we see a reasonable correlation between Social status(also known as family) and Happiness score.
